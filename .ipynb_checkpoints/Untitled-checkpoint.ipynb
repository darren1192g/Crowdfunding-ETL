# %%
import pandas as pd
import json
import re
import numpy as np

# %%
# Read the data into a Pandas DataFrame
bi = pd.read_csv("backer_info.csv", header= [0, 1])
# Get the sheet names.
bi
# Out:
#                                                                                       backer_info
#      {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 0     {"backer_id": "ha127", "cf_id": 563, "name": "...
# 1     {"backer_id": "lg794", "cf_id": 65, "name": "L...
# 2     {"backer_id": "tb566", "cf_id": 563, "name": "...
# 3     {"backer_id": "lh506", "cf_id": 563, "name": "...
# 4     {"backer_id": "lh382", "cf_id": 563, "name": "...
# ...                                                 ...
# 8169  {"backer_id": "st581", "cf_id": 65, "name": "S...
# 8170  {"backer_id": "gf637", "cf_id": 563, "name": "...
# 8171  {"backer_id": "rc983", "cf_id": 1114, "name": ...
# 8172  {"backer_id": "cz381", "cf_id": 65, "name": "C...
# 8173  {"backer_id": "fg535", "cf_id": 65, "name": "F...
#
# [8174 rows x 1 columns]

# %%
bi['backer_id'] = bi['backer_info'].str.extract(r'([^banker_idil\s+][\d])')
bi.head(10)
# Out:
#                                          backer_info backer_id  \
# 0  {"backer_id": "av166", "cf_id": 968, "name": "...        v1
# 1  {"backer_id": "ha127", "cf_id": 563, "name": "...        12
# 2  {"backer_id": "lg794", "cf_id": 65, "name": "L...        g7
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "...        56
# 4  {"backer_id": "lh506", "cf_id": 563, "name": "...        h5
# 5  {"backer_id": "lh382", "cf_id": 563, "name": "...        h3
# 6  {"backer_id": "em444", "cf_id": 563, "name": "...        m4
# 7  {"backer_id": "at582", "cf_id": 1572, "name": ...        t5
# 8  {"backer_id": "id772", "cf_id": 1911, "name": ...        77
# 9  {"backer_id": "lw275", "cf_id": 65, "name": "L...        w2
#
#                name                   email cf_id
# 0    Angelo Vincent      avincent@live.com}    v1
# 1     Hubert Arnold     harnold@yandex.com}    12
# 2      Loris Goulet     lgoulet@yandex.com}    g7
# 3  Teodora Brunelli  tbrunelli@outlook.com}    56
# ...

# %%
bi['cf_id'] = bi['backer_info'].str.extract(r'([^cf_id\s+][\d])')
bi.head()
# Out:
#                                          backer_info backer_id  \
# 0  {"backer_id": "av166", "cf_id": 968, "name": "...        v1
# 1  {"backer_id": "ha127", "cf_id": 563, "name": "...        12
# 2  {"backer_id": "lg794", "cf_id": 65, "name": "L...        g7
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "...        56
# 4  {"backer_id": "lh506", "cf_id": 563, "name": "...        h5
#
#                name                   email cf_id
# 0    Angelo Vincent      avincent@live.com}    v1
# 1     Hubert Arnold     harnold@yandex.com}    a1
# 2      Loris Goulet     lgoulet@yandex.com}    g7
# 3  Teodora Brunelli  tbrunelli@outlook.com}    b5
# 4        Lexie Hunt         lhunt@live.com}    h5

# %%
bi['name'] = bi['backer_info'].str.extract(r'([^nameil\s+][A-Za-z]+\s+[A-Za-z]+)').apply(lambda s:s.str.replace('"', ""))
bi.head()
# Out:
#                                          backer_info backer_id  \
# 0  {"backer_id": "av166", "cf_id": 968, "name": "...        v1
# 1  {"backer_id": "ha127", "cf_id": 563, "name": "...        a1
# 2  {"backer_id": "lg794", "cf_id": 65, "name": "L...        g7
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "...        b5
# 4  {"backer_id": "lh506", "cf_id": 563, "name": "...        h5
#
#                name                   email cf_id
# 0    Angelo Vincent      avincent@live.com}    v1
# 1     Hubert Arnold     harnold@yandex.com}    12
# 2      Loris Goulet     lgoulet@yandex.com}    g7
# 3  Teodora Brunelli  tbrunelli@outlook.com}    56
# 4        Lexie Hunt         lhunt@live.com}    h5

# %%
bi['email'] = bi['backer_info'].str.extract(r'(\S+@\S+)').apply(lambda s:s.str.replace('"', ""))
bi.head()
# Out:
#                                          backer_info backer_id  \
# 0  {"backer_id": "av166", "cf_id": 968, "name": "...        v1
# 1  {"backer_id": "ha127", "cf_id": 563, "name": "...        a1
# 2  {"backer_id": "lg794", "cf_id": 65, "name": "L...        g7
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "...        b5
# 4  {"backer_id": "lh506", "cf_id": 563, "name": "...        h5
#
#                name                   email cf_id
# 0    Angelo Vincent      avincent@live.com}    v1
# 1     Hubert Arnold     harnold@yandex.com}    12
# 2      Loris Goulet     lgoulet@yandex.com}    g7
# 3  Teodora Brunelli  tbrunelli@outlook.com}    56
# 4        Lexie Hunt         lhunt@live.com}    h5

# %%
bi_df = bi[['backer_id', 'name', 'email', 'cf_id']]
bi_df.head()
# Out:
#   backer_id              name                   email cf_id
# 0        v1    Angelo Vincent      avincent@live.com}    v1
# 1        a1     Hubert Arnold     harnold@yandex.com}    12
# 2        g7      Loris Goulet     lgoulet@yandex.com}    g7
# 3        b5  Teodora Brunelli  tbrunelli@outlook.com}    56
# 4        h5        Lexie Hunt         lhunt@live.com}    h5
